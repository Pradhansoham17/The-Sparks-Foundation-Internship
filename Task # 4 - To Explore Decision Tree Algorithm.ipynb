# %% [markdown]
# <font size='6'><b> #Task 4 - Decision Tree Algorithm</b></font>

# %% [markdown]
# <font size='6'><b>Soham Pradhan</b></font>

# %% [markdown]
# <font size='5'><b>Importing the Libraries :-</b></font>

# %%
# after removing data row as index row and changing column names
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# <font size='5'><b>Loading the Iris Dataset into a Pandas Dataframe :-</b></font>

# %%
df = pd.read_csv('C:\\Users\\soham\\Downloads\\Iris.csv')
df = df.drop(['Id'], axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <font size='5'><b>Data Visualization with the help of Seaborn and Matplotlib :-</b></font>

# %%
# Set Style
sns.set_style('whitegrid')

# %%
fig, ax = plt.subplots(figsize=(7.5,7.5))
plt.title('Scatterplot')
sns.catplot(ax=ax, x="Species", y="SepalLengthCm", data=df)
plt.close(2)

# %%
# Box-Plot
fig, ax = plt.subplots(figsize=(7.5,7.5))
plt.title('Box-plot')
sns.catplot(ax=ax, x="Species", y="SepalLengthCm", kind="box", data=df)
plt.close(2)

# %%
# Violin plot
fig, ax = plt.subplots(figsize=(7.5,7.5))
plt.title('Violin Plot')
sns.catplot(ax=ax, x="Species", y="SepalLengthCm", kind="violin", data=df)
plt.close(2)

# %%
#  Density Plot - To display the distribution between two variables (SepalLengthCm, SepalWidthCm in this case)
fig, ax = plt.subplots(figsize=(7.5,7.5))
plt.title('Density Plot')
sns.kdeplot(df.SepalLengthCm, df.SepalWidthCm)
plt.close(2)

# %%
# Calculate correlations
corr = df.corr()
 
# Heatmap
fig, ax = plt.subplots(figsize=(7.5,7.5))
plt.title('Heat Map')
sns.heatmap(corr)
plt.close(2)

# %%
sns.pairplot(df, hue="Species")

# %% [markdown]
# <font size='5'><b>Splitting the Dataset into training and testing :-</b></font>

# %%
from sklearn.model_selection import train_test_split
X, y = df.iloc[:,:-1],df.iloc[:,[-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 126            6.2           2.8            4.8           1.8
# 61             5.9           3.0            4.2           1.5
# 124            6.7           3.3            5.7           2.1
# 117            7.7           3.8            6.7           2.2
# 20             5.4           3.4            1.7           0.2
# ..             ...           ...            ...           ...
# 8              4.4           2.9            1.4           0.2
# 73             6.1           2.8            4.7           1.2
# 144            6.7           3.3            5.7           2.5
# 118            7.7           2.6            6.9           2.3
# 99             5.7           2.8            4.1           1.3
#
# [105 rows x 4 columns]

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 82             5.8           2.7            3.9           1.2
# 134            6.1           2.6            5.6           1.4
# 114            5.8           2.8            5.1           2.4
# 42             4.4           3.2            1.3           0.2
# 109            7.2           3.6            6.1           2.5
# 57             4.9           2.4            3.3           1.0
# 1              4.9           3.0            1.4           0.2
# 70             5.9           3.2            4.8           1.8
# 25             5.0           3.0            1.6           0.2
# 84             5.4           3.0            4.5           1.5
# 66             5.6           3.0            4.5           1.5
# 133            6.3           2.8            5.1           1.5
# 102            7.1           3.0            5.9           2.1
# 107            7.3           2.9            6.3           1.8
# ...

# %% [markdown]
# <font size='5'><b>Applying the Sklearn Decision-Tree Classifier on our training data :-</b></font>

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
X = X_train
y = y_train
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
clf.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
clf.n_features_
# Out:
# 4

# %% [markdown]
# <font size='5'><b>Predicting the results of Test Data and Checking Accuracy score :-</b></font>

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor'],
#       dtype=object)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9555555555555556

# %% [markdown]
# <font size='5'><b>Confusion Matrix and Classification Report :-</b></font>

# %%
from sklearn.metrics import confusion_matrix
y_true = y_test['Species']
confusion_matrix(y_true, y_pred)
# Out:
# array([[15,  0,  0],
#        [ 0, 14,  2],
#        [ 0,  0, 14]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=clf.classes_))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      0.88      0.93        16
#  Iris-virginica       0.88      1.00      0.93        14
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# <font size='5'><b>Visualizing the Decision Tree formed by our model :-</b></font>

# %%
from sklearn import tree
fig, ax = plt.subplots(figsize=(12, 12))
tree.plot_tree(clf,feature_names=df.iloc[:,:-1].columns,  
                                class_names =clf.classes_, filled=True, rounded=True, fontsize=12)
plt.show()

# %% [markdown]
# <font size='5'><b>Using Graphviz to export our Decision Tree to a PDF File :-</b></font>

# %%
import graphviz 
dot_data = tree.export_graphviz(clf,feature_names=df.iloc[:,:-1].columns,  
                                class_names = clf.classes_, filled=True, rounded=True,  
                                special_characters=True, out_file=None) 

graph = graphviz.Source(dot_data) 
graph.render("Graphviz_Decision Tree")
# Out:
# 'Graphviz_Decision Tree.pdf'
